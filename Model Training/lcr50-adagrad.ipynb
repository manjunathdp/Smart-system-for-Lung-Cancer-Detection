# %%
Adagrad=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    name="Adagrad"
)

# %%
from tqdm import tqdm
from numpy import asarray
import tensorflow as tf
import keras
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50
#from keras.applications.resnet import ResNet50
#from keras.applications.resnet import ResNet50
from tensorflow.keras.applications.resnet import decode_predictions
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input,UpSampling2D,Flatten,BatchNormalization,Dense,Dropout,GlobalAveragePooling2D
from tensorflow.keras import optimizers
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from glob import glob
from PIL import Image
import pandas as pd
import os

# %%
IMAGE_SIZE = [512, 512]

train_path = '/kaggle/input/lung-cancer-dataset/Lung cancer dataset/train'
val_path = '/kaggle/input/lung-cancer-dataset/Lung cancer dataset/val'

folders = glob(train_path+'/*')
print("Number of classes:",len(folders))
num_classes = len(folders)
nb_epochs = 30

resnet=ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# Fixed for our dataset
NUM_CLASSES = num_classes

# Fixed for Cats & Dogs color images
CHANNELS = 3

IMAGE_RESIZE = 512
RESNET50_POOLING_AVERAGE = 'avg'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'

# Common accuracy metric for all outputs, but can use different metrics for different output
LOSS_METRICS = ['accuracy']

# EARLY_STOP_PATIENCE must be < NUM_EPOCHS
#NUM_EPOCHS = 60
#EARLY_STOP_PATIENCE = 3

# These steps value should be proper FACTOR of no.-of-images in train & valid folders respectively
# Training images processed in each step would be no.-of-train-images / STEPS_PER_EPOCH_TRAINING
STEPS_PER_EPOCH_TRAINING = 10
STEPS_PER_EPOCH_VALIDATION = 2

# These steps value should be proper FACTOR of no.-of-images in train & valid folders respectively
# NOTE that these BATCH* are for Keras ImageDataGenerator batching to fill epoch step input
BATCH_SIZE_TRAINING =64
BATCH_SIZE_VALIDATION =32

from tensorflow.keras.models import Model,Sequential
model4 = Sequential()

# 1st layer as the lumpsum weights from resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# NOTE that this layer will be set below as NOT TRAINABLE, i.e., use it as is
model4.add(ResNet50(include_top = False, pooling = RESNET50_POOLING_AVERAGE, weights = 'imagenet'))

# 2nd layer as Dense for 2-class classification, i.e., dog or cat using SoftMax activation
model4.add(Dense(num_classes, activation = 'softmax'))

# Say not to train first layer (ResNet) model as it is already trained
model4.layers[0].trainable = False

model4.summary()

from tensorflow.keras import optimizers

sgd = optimizers.SGD(learning_rate = 0.001, momentum = 0.9, nesterov = True)
RMSprop=tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    name="RMSprop"
)
AdamW=tf.keras.optimizers.experimental.AdamW(
    learning_rate=0.001,
    name="AdamW"
)
Adadelta=tf.keras.optimizers.Adadelta(
    learning_rate=0.001,
    name="Adadelta"
)
Adagrad=tf.keras.optimizers.Adagrad(
    learning_rate=0.001,
    name="Adagrad"
)
model4.compile(optimizer = Adagrad, loss = OBJECTIVE_FUNCTION, metrics = LOSS_METRICS)





from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_size = IMAGE_RESIZE

data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = data_generator.flow_from_directory(
        train_path,
        target_size=(image_size, image_size),
        batch_size=BATCH_SIZE_TRAINING,
        class_mode='categorical')


validation_generator = data_generator.flow_from_directory(
        val_path,
        target_size=(image_size, image_size),
        batch_size=BATCH_SIZE_VALIDATION,
        class_mode='categorical')

history = model4.fit(
        train_generator,
        epochs = nb_epochs,
        validation_data=validation_generator#,
    #steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
    #validation_steps=STEPS_PER_EPOCH_VALIDATION
        
        )

model4.save("Adagrad_trial_6_classification_using_resnet50.h5")
print("Saved model to disk")

df = pd.DataFrame(history.history)
df.to_csv('Adagrad_trial_6_Resnet50history.csv',index = False)
# Out:
# Number of classes: 3
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense (Dense)               (None, 3)                 6147
#
# =================================================================
# Total params: 23,593,859
# Trainable params: 6,147
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Found 950 images belonging to 3 classes.
# Found 134 images belonging to 3 classes.
# Epoch 1/30
# 15/15 [==============================] - 35s 2s/step - loss: 0.9250 - accuracy: 0.6653 - val_loss: 0.7694 - val_accuracy: 0.7463
# Epoch 2/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.6769 - accuracy: 0.8053 - val_loss: 0.6840 - val_accuracy: 0.8060
# Epoch 3/30
# 15/15 [==============================] - 21s 1s/step - loss: 0.6101 - accuracy: 0.8316 - val_loss: 0.6279 - val_accuracy: 0.8358
# Epoch 4/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.5668 - accuracy: 0.8463 - val_loss: 0.5965 - val_accuracy: 0.8284
# Epoch 5/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.5351 - accuracy: 0.8526 - val_loss: 0.5637 - val_accuracy: 0.8657
# Epoch 6/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.5128 - accuracy: 0.8579 - val_loss: 0.5432 - val_accuracy: 0.8657
# Epoch 7/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4929 - accuracy: 0.8579 - val_loss: 0.5291 - val_accuracy: 0.8657
# Epoch 8/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.4777 - accuracy: 0.8600 - val_loss: 0.5162 - val_accuracy: 0.8657
# Epoch 9/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4629 - accuracy: 0.8611 - val_loss: 0.5008 - val_accuracy: 0.8731
# Epoch 10/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4508 - accuracy: 0.8653 - val_loss: 0.4940 - val_accuracy: 0.8657
# Epoch 11/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4419 - accuracy: 0.8632 - val_loss: 0.4793 - val_accuracy: 0.8731
# Epoch 12/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4325 - accuracy: 0.8632 - val_loss: 0.4668 - val_accuracy: 0.8806
# Epoch 13/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.4241 - accuracy: 0.8642 - val_loss: 0.4642 - val_accuracy: 0.8806
# Epoch 14/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4162 - accuracy: 0.8653 - val_loss: 0.4562 - val_accuracy: 0.8806
# Epoch 15/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.4100 - accuracy: 0.8653 - val_loss: 0.4493 - val_accuracy: 0.8806
# Epoch 16/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.4036 - accuracy: 0.8653 - val_loss: 0.4406 - val_accuracy: 0.8806
# Epoch 17/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3985 - accuracy: 0.8653 - val_loss: 0.4379 - val_accuracy: 0.8806
# Epoch 18/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3925 - accuracy: 0.8653 - val_loss: 0.4359 - val_accuracy: 0.8806
# Epoch 19/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3881 - accuracy: 0.8663 - val_loss: 0.4290 - val_accuracy: 0.8806
# Epoch 20/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3827 - accuracy: 0.8663 - val_loss: 0.4248 - val_accuracy: 0.8806
# Epoch 21/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3786 - accuracy: 0.8663 - val_loss: 0.4230 - val_accuracy: 0.8806
# Epoch 22/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3743 - accuracy: 0.8674 - val_loss: 0.4207 - val_accuracy: 0.8806
# Epoch 23/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3707 - accuracy: 0.8653 - val_loss: 0.4146 - val_accuracy: 0.8806
# Epoch 24/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3676 - accuracy: 0.8674 - val_loss: 0.4136 - val_accuracy: 0.8806
# Epoch 25/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3638 - accuracy: 0.8684 - val_loss: 0.4098 - val_accuracy: 0.8806
# Epoch 26/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3602 - accuracy: 0.8684 - val_loss: 0.4057 - val_accuracy: 0.8806
# Epoch 27/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3572 - accuracy: 0.8695 - val_loss: 0.4029 - val_accuracy: 0.8806
# Epoch 28/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3543 - accuracy: 0.8695 - val_loss: 0.3999 - val_accuracy: 0.8806
# Epoch 29/30
# 15/15 [==============================] - 19s 1s/step - loss: 0.3512 - accuracy: 0.8716 - val_loss: 0.3973 - val_accuracy: 0.8806
# Epoch 30/30
# 15/15 [==============================] - 20s 1s/step - loss: 0.3484 - accuracy: 0.8705 - val_loss: 0.3961 - val_accuracy: 0.8806
# Saved model to disk

# %% [markdown]
# # **Predication**

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model

# Load the model from the H5 file
model = load_model('/kaggle/input/lcr50-weights/Adagrad_trial_6_classification_using_resnet50.h5')

DIRECTORY= "/kaggle/input/lung-cancer-dataset/Lung cancer dataset/test"
class_names=['Bengin case','Malignant case','Normal case']

data = {'class': [],
        'predicate_class': [],
        'status': []}
pcount=0
fcount=0
totalb=totalm=totaln=fb=fm=fn=0.0
df = pd.DataFrame(data)
for img in os.listdir(DIRECTORY):
    img_path=os.path.join(DIRECTORY,img)
    img_array=cv2.imread(img_path)
    img_array=cv2.resize(img_array,(512,512))
    img_array_=img_array
    img_array_=np.expand_dims(img_array_,axis=0)
    pred=model.predict(np.array(img_array_))
    output_class=class_names[np.argmax(pred)]
    s=img.split()
    ctemp=s[0]+" "+s[1]
    if(ctemp=='Bengin case'):
        totalb=totalb+1
    if(ctemp=='Malignant case'):
        totalm=totalm+1
    if(ctemp=='Normal case'):
        totaln=totaln+1
    if(ctemp==output_class):
        temp = {'class': ctemp, 'predicate_class': output_class , 'status':'pass'}
        pcount=pcount+1
        df = df.append(temp, ignore_index=True)
    else :
        temp = {'class': ctemp, 'predicate_class': output_class , 'status':'fail'}
        fcount=fcount+1
        df = df.append(temp, ignore_index=True)

        if(ctemp=='Bengin case'):
            fb=fb+1
        if(ctemp=='Malignant case'):
            fm=fm+1
        if(ctemp=='Normal case'):
            fn=fn+1
print("Predication Accuracy of each class")
print('Bengin case',(((totalb-fb)/totalb)*100))
print('Malignant case',(((totalm-fm)/totalm)*100))
print('Normal case',(((totaln-fn)/totaln)*100))
print("Predication Accuracy of the model is ",(pcount/(pcount+fcount)*100))
print("Pass count=",pcount)
print("Fail count=",fcount)
df
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 395ms/step
# Predication Accuracy of each class
# Bengin case 0.0
# Malignant case 100.0
# Normal case 75.0
# Predication Accuracy of the model is  53.84615384615385
# Pass count= 7
# Fail count= 6
#              class predicate_class status
# 0      Normal case     Normal case   pass
# 1   Malignant case  Malignant case   pass
# 2   Malignant case  Malignant case   pass
# 3      Bengin case     Normal case   fail
# 4      Bengin case     Normal case   fail
# 5      Bengin case     Normal case   fail
# 6   Malignant case  Malignant case   pass
# 7      Bengin case     Normal case   fail
# 8      Normal case     Normal case   pass
# 9   Malignant case  Malignant case   pass
# 10     Normal case     Normal case   pass
# 11     Bengin case     Normal case   fail
# 12     Normal case  Malignant case   fail

# %%
df.to_csv('Adagrad_data.csv', index=False)
