# %% [markdown]
# # **ResNET50 Arch with different optimizers**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
#   # 1. **SGD**

# %%
 
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/SGD_trial_1.1_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 97.78947234153748
#  Validation Accuracy= 86.56716346740723
#  Training Loss= 9.92831662297248
#  Validation Loss= 35.47598123550415

# %% [markdown]
# # **Adam**

# %%
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/Adam_trial_2_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 97.78947234153748
#  Validation Accuracy= 86.56716346740723
#  Training Loss= 9.92831662297248
#  Validation Loss= 35.47598123550415

# %% [markdown]
# # **RMSprop**

# %%
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/RMSprop_trial_3_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 96.73684239387512
#  Validation Accuracy= 88.05969953536987
#  Training Loss= 9.991339594125739
#  Validation Loss= 33.21143686771393

# %% [markdown]
# # **AdamW**

# %%
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/AdamW_trial_4_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 97.15789556503296
#  Validation Accuracy= 88.05969953536987
#  Training Loss= 9.3274749815464
#  Validation Loss= 34.44732129573822

# %% [markdown]
# # **Adadelta**

# %%
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/Adadelta_trial_5_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 58.31578969955444
#  Validation Accuracy= 50.0
#  Training Loss= 90.19550681114195
#  Validation Loss= 97.75400757789612

# %% [markdown]
# # **Adagrad**

# %%
# reading the CSV file
history = pd.read_csv('/kaggle/input/lcr50graph/Adagrad_trial_6_Resnet50history.csv')

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
print("epochs=30\n"+"Training Accuracy=",acc[29]*100,"\n Validation Accuracy=",
      val_acc[29]*100,"\n Training Loss=",loss[29]*100,
      "\n Validation Loss=",val_loss[29]*100)
# Out:
# epochs=30
# Training Accuracy= 87.05263137817383
#  Validation Accuracy= 88.05969953536987
#  Training Loss= 34.836485981941216
#  Validation Loss= 39.61488604545593
